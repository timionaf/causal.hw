# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.5 MB 12.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.5 MB 9.7 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.5 MB 10.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 9.9 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------------------- -------------- 1.6/2.5 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 8.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.7 MB 9.2 MB/s eta 0:00:02
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.8 MB 16.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 16.7 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
#Problem 2 - PartB 
# a)

def sample_full_distribution(n, sigma, tau):
    epsilon = np.random.normal(0,np.power(sigma, 2), n)
    
    x = np.random.uniform(-5,5,n)
    y0 = 1/(1+exp(-x)) + epsilon
    y1 = y0 + tau
    
    z = np.random.binomial(n,p=1/2)
    
    draws = {x,y0,y1,z}
    #load n iid draws into a DataFrame object:
    full_data = pd.DataFrame(draws)
    return(full_data)

# %%
# b) 
  
def reveal_outcomes(full_data):
    def obs(y,x,z):
        x = np.random.uniform(-5,5,n)
        y0 = 1/(1+exp(-x)) + epsilon
        y1 = y0 + tau

        z = np.random.binomial(n,p=1/2)
        
        
        if z == 1: 
             y = y1 
        else:
            y=y0
    obs_data = pd.DataFrame(obs)
    return(obs_data)
# Out:
#   Cell In[15], line 12
#     return y = y1
#              ^
# SyntaxError: invalid syntax
